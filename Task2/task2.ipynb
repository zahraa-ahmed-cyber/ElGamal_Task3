# %%
from roboflow import Roboflow

rf = Roboflow(api_key="jJmtIG4Zzq6GPJV5b4lM")
project = rf.workspace("cv-6ehzn").project("od-cte7x")
version = project.version(3)
dataset = version.download("yolov8")

# %%
# from ultralytics import YOLO

# model = YOLO("yolov8n.yaml")
# model.train(data="data.yaml", epochs=40)



# import torch
from ultralytics import YOLO

# Specify the device
# device = "cuda" if torch.cuda.is_available() else "cpu"
device = "cpu"

# Load the model and specify the device
model = YOLO("runs/detect/train8/weights/last.pt").to(device)

# Train the model
model.train(data="data.yaml", epochs=40, device=device,resume=True)


# import torch
# print(torch.cuda.is_available())
# Out:
# New https://pypi.org/project/ultralytics/8.1.47 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cu118 CPU (AMD Ryzen 9 7950X 16-Core Processor)
# ...
